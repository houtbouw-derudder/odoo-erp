# %% [markdown]
# The idea is:
# - to add a field **include_in_progress_report** on stage (task-type)
# - to keep track of quantity, price and progress on those tasks that belong to a stage marked with **include_in_progress_report**
# - create new types ProgressReport and TaskProgress as a way to take snapshots of the task information and use that to generate reports
# - link invoices to project in order to be able to keep track of the total amount invoiced for a specific project

# %%
print("Hello world")
# Out:
# Hello world
